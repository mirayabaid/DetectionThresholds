# %%
# setup
from Package import StaircaseSimulation
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import norm
import random

# %%
# plotting the psychometric function, calculating the stimulus intensity at which p(correct response) = 0.5 in a 2AFC 3up1down staircase 

stimulus_range, pr_correct = StaircaseSimulation.GetPsychometricFunction(PsychometricCurveMu = 50,
                                 PsychometricCurveSigma = 10,
                                 StimulusIntensityStart = 0, 
                                 StimulusIntensityStop = 100)

target_probability, NumAFC, Criterion = StaircaseSimulation.GetStaircaseConvergenceTarget(NumAFC = 2, 
                                    Criterion = (3,1))

target_intensity = StaircaseSimulation.GetStaircaseConvergenceIntensity(stimulus_range, pr_correct, target_probability)

StaircaseSimulation.PlotPsychometricFunctionTarget(stimulus_range, pr_correct, target_probability, target_intensity, Criterion, NumAFC)

# %%
''' running the staircase simulation '''

Trial_Amplitude_History, Reversion_Amplitude_History, Detection_History, Num_Trials_History, Threshold_History, Reversion_Trials_History = StaircaseSimulation.SimulateTransformedStaircase(NumSimulations = 1000, 
                                 PsychometricCurveMu = 50,
                                 PsychometricCurveSigma = 10,
                                 StimulusIntensityStart = 0, # start of stimulus intensity range 
                                 StimulusIntensityStop = 100, # end of stimulus intensity range 
                                 MaxNumTrials = 1000, 
                                 MaxReversions = 10,  
                                 NumAFC = 2, 
                                 Criterion = (3,1), 
                                 InitialStepSize = 5, 
                                 StepFactor = 0.725,
                                 NumInitialReversionsSkipped = 0)


# example staircase plot 
StaircaseSimulation.PlotExampleStaircase(Trial_Amplitude_History,
                         Reversion_Amplitude_History,
                         Threshold_History,
                         Detection_History, 
                         Num_Trials_History,
                         SimulationNumber = 6)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 18
#       3 Trial_Amplitude_History, Reversion_Amplitude_History, Detection_History, Num_Trials_History, Threshold_History, Reversion_Trials_History = StaircaseSimulation.SimulateTransformedStaircase(NumSimulations = 1000,
#       4                                  PsychometricCurveMu = 50,
#       5                                  PsychometricCurveSigma = 10,
#    (...)
#      13                                  StepFactor = 0.725,
#      14                                  NumInitialReversionsSkipped = 0)
#      17 # example staircase plot
# ---> 18 StaircaseSimulation.PlotExampleStaircase(Trial_Amplitude_History,
#      19                          Reversion_Amplitude_History,
#      20                          Threshold_History,
#      21                          Detection_History,
#      22                          Num_Trials_History,
#      23                          SimulationNumber = 6)
#
# File ~\Documents\GitHub\DetectionThresholds\Package\StaircaseSimulation.py:166, in PlotExampleStaircase(Trial_Amplitude_History, Reversion_Amplitude_History, Threshold_History, Detection_History, Num_Trials_History, SimulationNumber)
#     157 def PlotExampleStaircase(Trial_Amplitude_History,
#     158                          Reversion_Amplitude_History,
#     159                          Threshold_History,
#     160                          Detection_History,
#     161                          Num_Trials_History,
#     162                          SimulationNumber = 1):
#     164     NumTrials = Num_Trials_History[SimulationNumber-1]
# --> 166     for trial in range(int(NumTrials-1)):
#     167         plt.step(trial, Trial_Amplitude_History[trial, SimulationNumber-1])
#     168         if Detection_History[trial, SimulationNumber-1] == 0:
#
# TypeError: only size-1 arrays can be converted to Python scalars
